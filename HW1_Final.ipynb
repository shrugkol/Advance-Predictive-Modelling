# %% [markdown]
# ### Jocelyne Walker (EID- jvw359) and Shruti Kolhatkar (EID-sgk637)
#
# # <p style="text-align: center;">MIS 382N: ADVANCED PREDICTIVE MODELING - MSBA</p>
# # <p style="text-align: center;">Assignment 1</p>
# ## <p style="text-align: center;">Total points: 85</p>
# ## <p style="text-align: center;">Due: Monday, September 14 submitted via Canvas by 11:59 pm</p>
#
# Your homework should be written in a **Jupyter notebook**. You may work in groups of two if you wish. Your partner needs to be from the same section. Only one student per team needs to submit the assignment on Canvas.  But be sure to include name and UTEID for both students.  Homework groups will be created and managed through Canvas, so please do not arbitrarily change your homework group. If you do change, let the TA know.
#
# Also, please make sure your code runs and the graphics (and anything else) are displayed in your notebook before submitting. (%matplotlib inline)

# %% [markdown]
# # Question 1: Challenges in Data Science (10 pts)
#
# Refer to the Domino guide under Modules --> Additional Resources
#
# Section 2 describes 8 Challenges. You may have personally encountered or heard of somebody else who encountered some of these challenge. If so, please write 1-2 paragraphs on what situation was encountered and how it mapped into one the mentioned challenges. If not, think of a hypothetical case and do the same exercise.

# %% [markdown]
# ## Answer
#
# **Hypothetical case:** Uber's Self Driving Cars
#
# This is a hypothetical case based off a real incident with Uber's self driving cars, where we are considering safety problems. Solving only a few good problems won't help here as they have to consider all possible problems. Missing even a single factor related to safety could cause an accident, just like it did. Uber was **solving a few good problems, but not solving enough problems at once.** If you are building a self-driving machine, you need to know what makes a good driver and be well-versed in the challenges and outcomes that accompany safe and reckless driving. These should be then reflected in the algorithms that drive the car, after which you can hone in different platforms and tools and dive deeper.
#
# The safety report of this accident states the self drive system could not determine whether the object involved in the accident was a pedestrian, vehicle, or bicycle. It also failed to correctly predict the path. The report clearly indicates "the system design did not include a consideration for jaywalking pedestrians." Additionally Uber’s organizational structure wasn’t built to catch safety errors, and its software included glaring safety holes. Apparently the cars were explicitly programmed not to react to an oncoming crash for the space of 1 second because the software saw so many “ghosts” that engineers seemed more worried about hard braking for no reason than because the vehicle was about to hit something. All possible problems concerned with the safety of self-driving cars should be considered to avoid accidents involving human lives.
#
# **Our experience:** Applying Data Science to Procurement
#
# When I worked at ExxonMobil, I was part of the IT Procurement team. Most of my team's time was spent procuring data and building contracts with vendors. This includes reading hundreds of pages of text, piecing together the most important points, and negotiating with supplier representatives. Our goals aligned with those described in the data science management article: building high-quality, reliable, scalable contracts. These contracts should meet certain objectives: for example, not indemnifying a supplier for gross negligence. However, with limited resources (contract managers and lawyers), it is nearly impossible to scale this process without simply increasing headcount.
#
# ExxonMobil Procurement (and most other procurement organizations) are **solving the right problem but have the wrong tools.** The article states: "Data scientists spend 80% of their time finding and cleaning data." For procurement associates, this is largely unstructured data as they act as "contract scientists." However, these professionals are largely unequipped to perform any high level analysis of the contracts they manage without reading them. This [Harvard Business Review article](https://hbr.org/2018/02/how-ai-is-changing-contracts) speaks to the application of Artificial Intelligence to quickly extract clauses, compare documents, and assess risk levels of hundreds of thousands of documents. Beyond just using a cloud system to store and organize contracts, there's huge potential to improve and even write contracts using AI. However, in ExxonMobil, there's little budget and a lot of red tape to implement a new procurement system. Without a significant industry shift or a serious human-error based complication in a contract, it is likely that this challenge will continue, and Procurement organizaitons will continue to rely on human processing rather than NLP computing resources to analyze contracts.

# %% [markdown]
# # Question 2: Guess the coin (5+5 = 10 points)
#
# Assume we are playing a guessing game with a friend. The friend has three coins at hand:
# * **Coin A**: a fair coin with equal probability of being head (H ) or tail (T)
# * **Coin B**: a biased coin with a probability of 0.75 being head (H)
# * **Coin C**: a coin with a probability of $P^*(H)$ being head (H)
#
# The friend secretly picked one of the coins, randomly flipped it a few times, and get a sequence of *HTHHTT* (all of which come from the same coin he picked).
#
# 1. If you had to choose between whether **Coin A** or **Coin B** was used, and you prefer the one which is more likely, which one will you choose?  (5 points)
# 2. What would be the value of  $P^*(H)$ such that **Coin C** corresponds to the most likely (among infinite possible coins) coin to have produced the observed sequence?(i.e. provide  an analytical derivation for $P^*(H)$ using maximum likelihood estimation (MLE))."

# %% [markdown]
# ## Answer

# %% [markdown]
# 1. The maximum likelihood principle states that we choose the estimator for the parameter $\theta$ that maximizes the likelihood of observing the actual sample given the probability density function for y. We take our observation (*HTHHTT*) and then "look back" to calculate the probability of Coin A versus Coin B resulting in this sample observation. Thus, for Coin A, our parameter is $\theta$ = 0.5. For Coin B, our parameter is $\theta$ = 0.75. Whichever value of P results in a higher probability of the sample occurring is the coin we determine was more likely used.
#     To solve this, we plug each value of P into the formula $L = (\theta)^{3}*((1-\theta)^{3})$
#
#     $$\operatorname{Likelihood} (\operatorname{coin} A)=\operatorname{P}(H T H H T T \mid \operatorname{coin} A)=(0.5)^{6} \approx 0.0156$$
#     $$\operatorname{Likelihood}(\operatorname{coin} B)=\operatorname{P}(H T H H T T \mid \operatorname{coin} B)=(0.75)^{3} \times(0.25)^{3} \approx 0.00659$$
#     $$\operatorname{Likelihood} (\operatorname{coin} A)>\operatorname{Likelihood}(\operatorname{coin} B)$$
#
#     **Coin A has a higher likelihood.** This makes sense because Heads and Tails are equally present in the sample, so the fair coin is more likely to have produced this sample.
#
#
# 2. The value of $P^*(H)$ that corresponds to the most likely coin to have produced the observed sequence is the value that maximizes the function $L = (\theta)^{3}*(1-\theta)^{3}$ subject to the constraint that P is between 0 and 1.In order to find the maximum value of this function, we take the , the natural logarithm of the likelihood function
#
# $(logL(\theta) = 3\log\theta + 3\log(1-\theta)$
#
#
#    We then solve for the maximum value of the function by setting $\frac{dL}{d\theta}$ equal to 0.
#
#
# $\frac{dL}{d\theta} = 3/\theta - 3/(1-\theta)$
#
# $0 = 3/\theta- 3/(1-\theta)$
#
# $3/\theta = 3/(1-\theta)$
#
# $1/\theta = 1/(1-\theta)$
#
# $\theta = 1-\theta $
#
# $\theta = \frac{1}{2}$
#
# Thus, the value of $P^*(H)$ such that Coin C corresponds to the most likely coin to have produced this sequence is **0.5.**

# %% [markdown]
# # Question 3: Multiple Linear Regression (30 pts)
#
# This dataset is a record of 7 common different fish species in fish market sales. With this dataset, a predictive model can be developed using machine friendly data and the weight of fish can be predicted. Use the following code to import the Fish market prices dataset in python. The dataset is taken from https://www.kaggle.com/aungpyaeap/fish-market.

# %%
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None


df = pd.read_csv("data.csv", index_col=0)
#df = df[~df.isin([0, np.nan, np.inf, -np.inf]).any(1)]
df.head()
# Out:
#          Weight  Length1  Length2  Length3   Height   Width
# Species
# Bream     242.0     23.2     25.4     30.0  11.5200  4.0200
# Bream     290.0     24.0     26.3     31.2  12.4800  4.3056
# Bream     340.0     23.9     26.5     31.1  12.3778  4.6961
# Bream     363.0     26.3     29.0     33.5  12.7300  4.4555
# Bream     430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# Here,
# 1. Species: Species name of fish
# 2. Weight: Weight of fish in gram
# 3. Length1: Vertical length in cm
# 4. Length2: Diagonal length in cm
# 5. Length3: Cross length in cm
# 6. Height: Height in cm
# 7. Width: Diagonal width in cm

# %%
df = df.fillna(0)
X = df.drop(['Weight'], axis=1)
y = df['Weight']

# %% [markdown]
# Consider the `Weight` column to be your target variable.

# %% [markdown]
# a. (2 pts)  Print the shape (number of rows and columns) of the feature matrix X, and print the first 5 rows.
#
# b. (6 pts) Using ordinary least squares, fit a multiple linear regression (MLR) on all the feature variables using the entire dataset. Report the regression coefficient of each input feature and evaluate the model using mean absolute error (MAE). Example of ordinary least squares in Python is shown in Section 1.1.1 of http://scikit-learn.org/stable/modules/linear_model.html.
#
# c. (6 pts) Split the data into a training set and a test set, using the train_test_split with test_size = 0.25 and random_state = 50. Fit an MLR using the training set. Evaluate the trained model using the training set and the test set, respectively. Compare the two MAE values thus obtained. Report the [$R^2$ (coefficient of determination)](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html) value.
#
# d. (5 pts) Calculate the pearson correlation matrix of the independent variables in the training set. Report the variables which have magnitude of correlation greater than 0.8 w.r.t the variable 'Length2'. Now, plot a pairplot based on Species column as seen in the 2nd plot [here](https://seaborn.pydata.org/generated/seaborn.pairplot.html). How does the pairplot validate your previous answer?
#
# e. (6 pts) Plot the histogram of Y_train and see its distribution. Now take log of Y_train and plot its histogram. Now run regression again after taking log and compare the MAE. You need to do np.exp(predictions) to bring them back to original scale, and then calculate MAE and $R^2$. Explain the results.
#
# f. (5 pts) Rank the features in descending order based on their significance. You might find this link to be helpful: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html.
#
# g. (Bonus question - 5 pts) Use the Species column for one-hot encoding and perform part c of this question. Explain your results.

# %% [markdown]
# ## Answer

# %% [markdown]
# a.

# %%
print(X.shape)
#159 rows, 5 columns

#print first 5 rows
print(X.iloc[:5])
# Out:
# (159, 5)
#          Length1  Length2  Length3   Height   Width
# Species
# Bream       23.2     25.4     30.0  11.5200  4.0200
# Bream       24.0     26.3     31.2  12.4800  4.3056
# Bream       23.9     26.5     31.1  12.3778  4.6961
# Bream       26.3     29.0     33.5  12.7300  4.4555
# Bream       26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# b.

# %%
from sklearn import metrics

reg = linear_model.LinearRegression()
reg.fit(X,y)

#list of coefficients
print('List of Coefficients')
print(list(zip(reg.coef_, X.columns)))

y_pred = reg.predict(X)
print('\nMean Absolute Error')
print(metrics.mean_absolute_error(y, y_pred))
# Out:
# List of Coefficients
# [(62.35521443246467, 'Length1'), (-6.526752492044475, 'Length2'), (-29.026218612693462, 'Length3'), (28.297351322276658, 'Height'), (22.47330665223733, 'Width')]
#
# Mean Absolute Error
# 91.78724088307943

# %% [markdown]
# c.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=50)
reg.fit(X_train, y_train)
print('List of Coefficients')
print(list(zip(reg.coef_, X_train.columns)))

y_train_pred = reg.predict(X_train)
print('\nMean Absolute Error - Train')
print(metrics.mean_absolute_error(y_train,y_train_pred))

print('\nModel R-Squared')
print(metrics.r2_score(y_train,y_train_pred))

y_test_pred = reg.predict(X_test)
print('\nMean Absolute Error - Test')
print(metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# List of Coefficients
# [(52.469000209092464, 'Length1'), (-0.6291262169025257, 'Length2'), (-26.738983114839247, 'Length3'), (27.97525039864424, 'Height'), (32.99388764566371, 'Width')]
#
# Mean Absolute Error - Train
# 84.82479753198535
#
# Model R-Squared
# 0.878916337517605
#
# Mean Absolute Error - Test
# 101.8948194505699

# %% [markdown]
# This model has a quite high R-Squared value of 0.87, and the training MAE has improved from the first model. However, we see a jump in the testing MAE.

# %% [markdown]
# d.

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import matplotlib.pyplot as plt

# print the Person correlation matrix
correlation_mat = X_train.corr()
sns.heatmap(correlation_mat, annot = True)
plt.show()

X_pairplot = X_train.reset_index(level=0)
sns.pairplot(X_pairplot, hue='Species')

# %% [markdown]
# The independent variables that have a correlation >0.8 w.r.t. Length2 are Length1, Length2, Length3, and Width.
#
# The pairplot validates this as the other variables that are most strongly positively correlated with Length2 are Length1, Length3, and Width. The correlation plot for Height is more spread out and thus not as strongly correlated as the other variables with Length2.

# %% [markdown]
# e.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.subplot(1,2,1)
plt.hist(y_train)
plt.title("Y Train")

plt.subplot(1,2,2)
y_train_log = np.log(y_train)
plt.hist(y_train_log)
plt.title("Log of Y Train")
plt.show()

reg.fit(X_train, y_train_log)
print('List of Coefficients')
print(list(zip(reg.coef_, X_train.columns)))

y_train_pred = reg.predict(X_train)
print('\nTrain Mean Absolute Error')
print(metrics.mean_absolute_error(y_train,np.exp(y_train_pred)))
print('\nModel R-Squared')
print(metrics.r2_score(y_train,np.exp(y_train_pred)))



y_test_pred = reg.predict(X_test)
print('\nTest Mean Absolute Error')
print(metrics.mean_absolute_error(y_test,np.exp(y_test_pred)))

print('\nThe mean absolute error is worse after the log(y) transformation.')
# Out:
# List of Coefficients
# [(-0.3213639855182367, 'Length1'), (0.31185714132579234, 'Length2'), (0.040164414183393816, 'Length3'), (0.0337551392366468, 'Height'), (0.3275820819175001, 'Width')]
#
# Train Mean Absolute Error
# 95.25208926559348
#
# Model R-Squared
# 0.7042361514462869
#
# Test Mean Absolute Error
# 176.83493472388568
#
# The mean absolute error is worse after the log(y) transformation.

# %% [markdown]
# After taking the log(y) and running the model, we see a decrease in the R-Squared to 0.70 and an increase in both the Train and Test MAE. This means that the log(y) model explains less of the variance than the original model. While the original histogram of Y-train did have a slight tail of right-skewed data, the log(y) transformation did not improve the model predictions.

# %% [markdown]
# f.

# %%
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

estimator = SVR(kernel="linear")
selector = RFE(estimator, n_features_to_select=1, step=.2)
selector = selector.fit(X_train, y_train)
selector.support_
print(selector.ranking_)
print(X_train.columns)
#1. Width, 2. Height, 3. Length2, 4.Length1, 5. Length3
# Out:
# [4 3 5 2 1]
# Index(['Length1', 'Length2', 'Length3', 'Height', 'Width'], dtype='object')

# %% [markdown]
# The predictors, from most significant to least significant, are 1. Width, 2. Height, 3. Length2, 4.Length1, 5. Length3.

# %% [markdown]
# g.

# %%
X_new= X.iloc[:, :].values
Z=pd.DataFrame(X)

# One Hot Encoding of categorical column called Species
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
lblencoder = LabelEncoder()
X_new[:, 0] = lblencoder.fit_transform(X_new[:, 0])

#onehotencoder = OneHotEncoder(categorical_features = [0])
ct = ColumnTransformer([("Species", OneHotEncoder(), [0])], remainder = 'passthrough')


X_new= ct.fit_transform(X_new.tolist())

#Split the data into training and test datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size = 0.25, random_state = 50)


reg.fit(X_train, y_train)
reg.coef_

y_train_pred = reg.predict(X_train)
print('\nMean Absolute Error - Train')
print(metrics.mean_absolute_error(y_train,y_train_pred))

print('\nModel R-Squared')
print(metrics.r2_score(y_train,y_train_pred))

y_test_pred = reg.predict(X_test)
print('\nMean Absolute Error - Test')
print(metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# Mean Absolute Error - Train
# 6.025584661458715
#
# Model R-Squared
# 0.9988033059533876
#
# Mean Absolute Error - Test
# 182.5091373728606

# %% [markdown]
# The mean absolute error drop by 78 points, which is drastic improvement in training model, Model R squared also increased by 0.12, however our tesing error increased by 80 points which says that our model is overfitting training data.

# %% [markdown]
# # Question 4 (30 pts)
#
# Using the same data from the previous question, in this question you will explore the application of Lasso and Ridge regression using sklearn package in Python. Use the same train and test data with additional augmented columns from before. Scale the data so that each of the independent variables have zero mean and unit variance. You can use the [sklearn.preprocessing.scale](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.scale.html) function for this.

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, RidgeCV, LassoCV
from sklearn.preprocessing import scale
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=50)

X_train_scaled = scale(X_train, axis=0, with_mean=True, with_std=True, copy=True)
X_test_scaled = scale(X_test, axis=0, with_mean=True, with_std=True, copy=True)

# %% [markdown]
# 1) Use sklearn.linear_model.Lasso and sklearn.linear_model.Ridge classes to do a [5-fold cross validation](http://scikit-learn.org/stable/auto_examples/exercises/plot_cv_diabetes.html#example-exercises-plot-cv-diabetes-py) using sklearn's [KFold](http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.KFold.html). For the sweep of the regularization parameter, we will look at a grid of values ranging from $\lambda = 10^{10}$ to $\lambda = 10^{-2}$. In Python, you can consider this range of values as follows:
#
#       import numpy as np
#
#       alphas =  10**np.linspace(10,-2,100)*0.5
#
#   Report the best chosen $\lambda$ based on cross validation. The cross validation should happen on your training data using  average MAE as the scoring metric. (8pts)
#
# 2) Run ridge and lasso for all of the alphas specified above (on training data), and plot the coefficients learned for each of them - there should be one plot each for lasso and ridge, so a total of two plots; the plots for different features for a method should be on the same plot. What do you qualitatively observe when value of the regularization parameter is changed? (7pts)
#
# 3) Run least squares regression, ridge, and lasso on the training data. For ridge and lasso, use only the best regularization parameter. Report the prediction error (MAE) on the test data for each. (5pts)
#
# 4) Run lasso again with cross validation using [sklearn.linear_model.LassoCV](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoCV.html). Set the cross validation parameters as follows:
#
#     LassoCV(alphas=None, cv=10, max_iter=10000)
#
# Report the best $\lambda$ based on cross validation. Run lasso on the training data using the best $\lambda$ and report the coefficeints for all variables. (5pts)
#
# 5) Why did we have to scale the data before regularization? (5pts)

# %% [markdown]
# ## Answer

# %% [markdown]
# 1.

# %%
import numpy as np
from sklearn.model_selection import KFold, GridSearchCV

alphas =  10**np.linspace(10,-2,100)*0.5
kr = KFold(n_splits=5)

lasso = Lasso(random_state=0, max_iter=10000)
ridge = Ridge(random_state=0, max_iter=10000)

tuned_parameters = [{'alpha': alphas}]

clf = GridSearchCV(lasso, tuned_parameters, cv=kr, refit=False, scoring = 'neg_mean_absolute_error')
clf.fit(X_train_scaled, y_train)
print('Lasso')
print(clf.best_params_)
alpha_L = clf.best_params_
#for lasso, 0.0815

crf = GridSearchCV(ridge, tuned_parameters, cv=kr, refit=False, scoring = 'neg_mean_absolute_error')
crf.fit(X_train_scaled, y_train)
print('\nRidge')
print(crf.best_params_)
alpha_R = crf.best_params_

#for ridge, 0.0267
# Out:
# Lasso
# {'alpha': 0.005}
#
# Ridge
# {'alpha': 0.005}

# %% [markdown]
# 2.

# %%
lasso = Lasso(max_iter = 10000, normalize = True)
coefs_L = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X_train_scaled, y_train)
    coefs_L.append(lasso.coef_)

plt.subplot(1,2,1)
ax = plt.gca()
ax.plot(alphas*2, coefs_L)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Lasso')



ridge = Ridge(max_iter = 10000, normalize = True)
coefs_R = []

for a in alphas:
    ridge.set_params(alpha=a)
    ridge.fit(X_train_scaled, y_train)
    coefs_R.append(ridge.coef_)

    
plt.subplot(1,2,2)
ax2 = plt.gca()
ax2.plot(alphas*2, coefs_R)
ax2.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Ridge')

plt.show()

# %% [markdown]
# As the value of the regularization parameter increases, the number of variables in the model for Lasso approaches 0 as the Lasso model can set variables exactly equal to 0. As the value of the regularization parameter increases, the Ridge coefficients shrink towards 0.

# %% [markdown]
# 3.

# %%
reg.fit(X_train_scaled, y_train)
y_test_pred = reg.predict(X_test_scaled)
print('\nLeast Squares Regression - Testing Data - Mean Absolute Error')
print(metrics.mean_absolute_error(y_test,y_test_pred))

clf = Lasso(alpha=alpha_L['alpha'],random_state=0, max_iter=10000)
clf.fit(X_train_scaled, y_train)
y_test_pred = clf.predict(X_test_scaled)
print('\nLasso - Testing Data - Mean Absolute Error')
print(metrics.mean_absolute_error(y_test,y_test_pred))

crf = Ridge(alpha=alpha_R['alpha'],random_state=0, max_iter=10000)
crf.fit(X_train_scaled, y_train)
y_test_pred = crf.predict(X_test_scaled)
print('\nRidge - Testing Data - Mean Absolute Error')
print(metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# Least Squares Regression - Testing Data - Mean Absolute Error
# 110.51179144666446
#
# Lasso - Testing Data - Mean Absolute Error
# 110.52985506457257
#
# Ridge - Testing Data - Mean Absolute Error
# 110.58911946237409

# %% [markdown]
# 4.

# %%
lasso_cv = LassoCV(alphas=None, cv=10, max_iter=10000)
lasso_cv.fit(X_train_scaled, y_train)
print("Best Lambda Based on Cross Validation")
print(lasso_cv.alpha_)

new_alpha = lasso_cv.alpha_
clf = Lasso(alpha=new_alpha,random_state=0, max_iter=10000)
clf.fit(X_train_scaled, y_train)

fmt = '{:<8}{:<20}{}'
print('\n')
print(fmt.format('', 'Predictor', 'Coef'))
for i, (predictor, coef) in enumerate(zip(X_train.columns, clf.coef_)):
    print(fmt.format(i, predictor, coef))

y_train_pred = clf.predict(X_train_scaled)
print('\nLasso - Training Data - Mean Absolute Error')
print(metrics.mean_absolute_error(y_train,y_train_pred))

print('\nLasso Model R-Squared')
print(metrics.r2_score(y_train,y_train_pred))

y_test_pred = clf.predict(X_test_scaled)
print('\nLasso - Testing Data - Mean Absolute Error')
print(metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# Best Lambda Based on Cross Validation
# 0.31003757262710946
#
#
#         Predictor           Coef
# 0       Length1             -268.62074722791823
# 1       Length2             506.0381076473601
# 2       Length3             -82.01843753644935
# 3       Height              68.75848840639274
# 4       Width               122.55555591940468
#
# Lasso - Training Data - Mean Absolute Error
# 86.15434126942073
#
# Lasso Model R-Squared
# 0.8984686400293462
#
# Lasso - Testing Data - Mean Absolute Error
# 111.62434173575829

# %% [markdown]
# 5.

# %% [markdown]
# We had to scale the data before regularization to treat all variables as equally weighted. Because fish are typically longer than they are wide, the feature for length would be preferred by the model much more than the features for width. This is because the variables with bigger scales can have smaller weights, and we prefer smaller weights in normalization. Once all variables are on the same scale, they are treated equally according to the regularization models.

# %% [markdown]
# # Question 5 (5 pts)
#
# Lasso and ridge regularization techniques are often used to combat overfitting during linear regression. Which of the two yields more sparse models (i.e. fewer number of parameters) when the tuning parameter $\lambda$ is sufficiently large (but not infinite)?

# %% [markdown]
# ## Answer

# %% [markdown]
# Lasso regularization yields more sparse models.
#
# Thiis is because the Lasso model allows coefficients to be exactly equal to 0, while the Ridge model only allows coefficients to be close to or approach 0. This means the Lasso model yields a fewer number of parameters than the Ridge. Our Lasso model set 2 of the coefficients equal to 0 in question 4, resulting in only 4 parameters instead of the Ridge model that requires 6.
